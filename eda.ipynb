# %% [markdown]
# # EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/Users/mitraazad/Documents/FHWN/SS25/QM_Datenanalyse/bds_tutorium_MM/Advanced Soybean Agricultural Dataset.csv')

# %%
data.head()
# Out:
#   Parameters Random   Plant Height (PH)  Number of Pods (NP)  \
# 0     C1S1G5      R1               50.5                130.3
# 1     C2S3G4      R1               44.5                132.0
# 2     C2S1G6      R1               52.2                150.0
# 3     C1S1G1      R1               50.5                140.8
# 4     C1S2G6      R2               49.2                175.6
#
#    Biological Weight (BW)  Sugars (Su)  \
# 0                   111.0        0.433
# 1                    80.0        0.334
# 2                    83.0        0.490
# 3                    66.0        0.163
# 4                    73.0        0.795
#
#    Relative Water Content in Leaves (RWCL)  ChlorophyllA663  Chlorophyllb649  \
# 0                                    0.732              1.4              3.1
# 1                                    0.674              7.1              2.2
# 2                                    0.677              1.8              1.3
# ...

# %%
data.describe()
# Out:
#        Plant Height (PH)  Number of Pods (NP)  Biological Weight (BW)  \
# count       55450.000000         55450.000000            55450.000000
# mean           49.959392           144.938979              114.533886
# std             3.052315            20.015994               48.925533
# min            40.400000            75.000000               32.000000
# 25%            49.200000           131.400000               80.000000
# 50%            50.300000           147.000000              102.000000
# 75%            52.000000           158.000000              133.000000
# max            55.700000           218.000000              236.000000
#
#         Sugars (Su)  Relative Water Content in Leaves (RWCL)  ChlorophyllA663  \
# count  55450.000000                             55450.000000     55450.000000
# mean       0.477543                                 0.673621         3.937670
# std        0.236294                                 0.084515         2.846317
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55450 entries, 0 to 55449
# Data columns (total 15 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Parameters                               55450 non-null  object
#  1   Random                                   55450 non-null  object
#  2   Plant Height (PH)                        55450 non-null  float64
#  3   Number of Pods (NP)                      55450 non-null  float64
#  4   Biological Weight (BW)                   55450 non-null  float64
#  5   Sugars (Su)                              55450 non-null  float64
#  6   Relative Water Content in Leaves (RWCL)  55450 non-null  float64
#  7   ChlorophyllA663                          55450 non-null  float64
#  8   Chlorophyllb649                          55450 non-null  float64
#  9   Protein Percentage (PPE)                 55450 non-null  float64
# ...

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.iloc[0]
# Out:
# Parameters                                 C1S1G5
# Random                                         R1
# Plant Height (PH)                            50.5
# Number of Pods (NP)                         130.3
# Biological Weight (BW)                      111.0
# Sugars (Su)                                 0.433
# Relative Water Content in Leaves (RWCL)     0.732
# ChlorophyllA663                               1.4
# Chlorophyllb649                               3.1
# Protein Percentage (PPE)                     33.2
# Weight of 300 Seeds (W3S)                    33.6
# Leaf Area Index (LAI)                        0.08
# Seed Yield per Unit Area (SYUA)            5567.4
# Number of Seeds per Pod (NSP)                1.86
# Protein Content (PCO)                        0.82
# Name: 0, dtype: object

# %%
data.copy()
# Out:
#       Parameters Random   Plant Height (PH)  Number of Pods (NP)  \
# 0         C1S1G5      R1               50.5                130.3
# 1         C2S3G4      R1               44.5                132.0
# 2         C2S1G6      R1               52.2                150.0
# 3         C1S1G1      R1               50.5                140.8
# 4         C1S2G6      R2               49.2                175.6
# ...          ...     ...                ...                  ...
# 55445     C1S1G2      R1               52.4                136.0
# 55446     C1S1G6      R1               45.7                145.0
# 55447     C1S2G2      R1               50.0                166.3
# 55448     C1S2G3      R3               44.0                209.0
# 55449     C2S3G3      R1               50.0                127.0
#
#        Biological Weight (BW)  Sugars (Su)  \
# 0                       111.0        0.433
# 1                        80.0        0.334
# 2                        83.0        0.490
# ...

# %%
data.to_excel('soybean.xlsx')

# %%
test = {t:3}
test.to_excel('test.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 test = {t:3}
#       2 test.to_excel('test.xlsx')
#
# NameError: name 't' is not defined

# %%
data = data['Random '].apply(lambda x: x + '$$$' if x == 'R1' else x)

# %%
data.head()
# Out:
# 0    R1$$$
# 1    R1$$$
# 2    R1$$$
# 3    R1$$$
# 4       R2
# Name: Random , dtype: object

# %%
data.isna().any()
# Out:
# False

# %%
sns.pairplot(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 sns.pairplot(data)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:2103, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2100     warnings.warn(msg, UserWarning)
#    2102 if not isinstance(data, pd.DataFrame):
# -> 2103     raise TypeError(
#    2104         f"'data' must be pandas DataFrame object, not: {type(data)}")
#    2106 plot_kws = {} if plot_kws is None else plot_kws.copy()
#    2107 diag_kws = {} if diag_kws is None else diag_kws.copy()
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'pandas.core.series.Series'>

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Seed Yield per Unit Area (SYUA)'], kde=True, color='green')
plt.title('Distribution of Soybean Yield')
plt.xlabel('Yield')
plt.ylabel('Frequency')
plt.show()
